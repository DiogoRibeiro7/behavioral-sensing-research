# %% [markdown]
# # Quickstart
# This notebook demonstrates loading synthetic data and running the analysis pipeline.

# %%
from sensor_modeling.utils.data_io import simulate_sensor_data
from sensor_modeling.analysis.pipeline import AnalysisPipeline

dataset = simulate_sensor_data(n_days=1)
pipe = AnalysisPipeline()
pipe.run_all(dataset)
